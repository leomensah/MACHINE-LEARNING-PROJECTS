# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonard-Boante-Mensah/LifeExpectancyProjects/blob/main/life_expectancy_gdp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/MY PROJECT DATASETS/Life-Expectancy-and-GDP-Starter/all_data.csv')

# %%
data.head(10)
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10
# 5   Chile  2005                              78.4  1.229650e+11
# 6   Chile  2006                              78.9  1.547880e+11
# 7   Chile  2007                              78.9  1.736060e+11
# 8   Chile  2008                              79.6  1.796380e+11
# 9   Chile  2009                              79.3  1.723890e+11

# %%
data.rename(columns={'Life expectancy at birth (years)': 'Life_Exp_at_Birth'}, inplace=True)
data.sample(20)
# Out:
#                      Country  Year  Life_Exp_at_Birth           GDP
# 49                    Mexico  2001               75.0  7.247040e+11
# 23                     China  2007               74.4  3.552180e+12
# 86                  Zimbabwe  2006               45.4  5.443896e+09
# 91                  Zimbabwe  2011               54.9  1.209845e+10
# 24                     China  2008               74.5  4.598210e+12
# 10                     Chile  2010               79.1  2.185380e+11
# 35                   Germany  2003               78.5  2.505730e+12
# 0                      Chile  2000               77.3  7.786093e+10
# 32                   Germany  2000               78.0  1.949950e+12
# 2                      Chile  2002               77.8  6.973681e+10
# 9                      Chile  2009               79.3  1.723890e+11
# 12                     Chile  2012               79.9  2.671220e+11
# 27                     China  2011               75.2  7.572550e+12
# ...

# %%
data.isnull().any()
# Out:
# Country              False
# Year                 False
# Life_Exp_at_Birth    False
# GDP                  False
# dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            96 non-null     object
#  1   Year               96 non-null     int64
#  2   Life_Exp_at_Birth  96 non-null     float64
#  3   GDP                96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB

# %%
data.describe(include='all')
# Out:
#          Country         Year  Life_Exp_at_Birth           GDP
# count         96    96.000000          96.000000  9.600000e+01
# unique         6          NaN                NaN           NaN
# top     Zimbabwe          NaN                NaN           NaN
# freq          16          NaN                NaN           NaN
# mean         NaN  2007.500000          72.789583  3.880499e+12
# std          NaN     4.633971          10.672882  5.197561e+12
# min          NaN  2000.000000          44.300000  4.415703e+09
# 25%          NaN  2003.750000          74.475000  1.733018e+11
# 50%          NaN  2007.500000          76.750000  1.280220e+12
# 75%          NaN  2011.250000          78.900000  4.067510e+12
# max          NaN  2015.000000          81.000000  1.810000e+13

# %%
data.groupby('Country').count()
# Out:
#                           Year  Life_Exp_at_Birth  GDP
# Country
# Chile                       16                 16   16
# China                       16                 16   16
# Germany                     16                 16   16
# Mexico                      16                 16   16
# United States of America    16                 16   16
# Zimbabwe                    16                 16   16

# %%
fig, ax = plt.subplots(figsize=(10, 7))
sns.barplot(data=data, x=data.Country, y=data.GDP)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
plt.hist(data.Life_Exp_at_Birth)
# Out:
# (array([ 8.,  2.,  2.,  2.,  2.,  0.,  0.,  5., 33., 42.]),
#  array([44.3 , 47.97, 51.64, 55.31, 58.98, 62.65, 66.32, 69.99, 73.66,
#         77.33, 81.  ]),
#  <a list of 10 Patch objects>)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
sns.lineplot(data= data, x=data.Year, y=data.GDP)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
sns.lineplot(data= data, x=data.Year, y=data.GDP, hue=data.Country)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
sns.lineplot(data= data, x=data.Year, y=data.Life_Exp_at_Birth)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
sns.lineplot(data= data, x=data.Year, y=data.Life_Exp_at_Birth, hue=data.Country)

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.violinplot(x=data.Country, y=data.GDP, scale='count')

# %%
fig, ax = plt.subplots(figsize=(15, 10))
plt.scatter(data.Life_Exp_at_Birth, data.GDP, norm=True)

# %%
fig, ax=plt.subplots(figsize=(15, 10))
plt.hist(data.GDP)
# Out:
# (array([52., 16.,  6.,  1.,  2.,  4.,  4.,  3.,  5.,  3.]),
#  array([4.41570280e+09, 1.81397413e+12, 3.62353256e+12, 5.43309099e+12,
#         7.24264942e+12, 9.05220785e+12, 1.08617663e+13, 1.26713247e+13,
#         1.44808831e+13, 1.62904416e+13, 1.81000000e+13]),
#  <a list of 10 Patch objects>)

# %%
data.groupby(data.Country).Life_Exp_at_Birth.mean()
# Out:
# Country
# Chile                       78.94375
# China                       74.26250
# Germany                     79.65625
# Mexico                      75.71875
# United States of America    78.06250
# Zimbabwe                    50.09375
# Name: Life_Exp_at_Birth, dtype: float64
